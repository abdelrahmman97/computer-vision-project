# %% [markdown]
# # computer vision project

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
img = plt.imread('test -1.png')

# %%
plt.imshow(img)

# %% [markdown]
# # Define vertical and horizontal Sobal Filters

# %%
vertical_filter = [[-1, -2, -1], [0, 0, 0], [1, 2, 1]]
horizontal_filter = [[-1, 0, 1], [-2, 0, 2], [-1, 0, 1]]

# %%
n, m, d = img.shape

# %% [markdown]
# # Apply vertical filter

# %%
vertical_edges_img = np.zeros_like(img)

# %%
for row in range(3, n-2):
    for col in range(3, m-2):
        local_pixels = img[row-1:row+2, col-1:col+2, 0]
        treansformed_pixels = vertical_filter*local_pixels
        vertical_score = (treansformed_pixels.sum() + 4)/8
        vertical_edges_img[row, col] = [vertical_score] * 3

# %%
plt.imshow(vertical_edges_img)

# %% [markdown]
# # Apply horizontal filter

# %%
horizontal_edges_img = np.zeros_like(img)

# %%
for row in range(3, n-2):
    for col in range(3, m-2):
        local_pixels = img[row-1:row+2, col-1:col+2, 0]
        treansformed_pixels = horizontal_filter*local_pixels
        horizontal_score = (treansformed_pixels.sum() + 4)/8
        horizontal_edges_img[row, col] = [horizontal_score] * 3

# %%
plt.imshow(horizontal_edges_img)

# %% [markdown]
# # Apply Both Vertical & Horizontal Filters

# %%
edges_img = np.zeros_like(img)

# %%
for row in range(3, n-2):
    for col in range(3, m-2):
        local_pixels = img[row-1:row+2, col-1:col+2, 0]

        vertical_treansformed_pixels = vertical_filter * local_pixels
        vertical_score = vertical_treansformed_pixels.sum() / 8

        horizontal_treansformed_pixels = horizontal_filter*local_pixels
        horizontal_score = horizontal_treansformed_pixels.sum() / 4
        
        edge_score = (vertical_score ** 2 + horizontal_score ** 2) ** 0.5
        edges_img[row, col] = [edge_score] * 3

edges_img = edges_img/edges_img.max()

# %%
plt.imshow(edges_img)

# %% [markdown]
# # Another example

# %%
img = plt.imread('OIP.jpg')
plt.imshow(img)

# %%
greyImg = img.mean(axis=2, keepdims=True)/255.0
greyImg = np.concatenate([greyImg]*3, axis=2)

# %%
plt.imshow(greyImg)

# %%
edges_img = np.zeros_like(greyImg)
n, m, d = greyImg.shape

# %%
for row in range(3, n-2):
    for col in range(3, m-2):
        local_pixels = img[row-1:row+2, col-1:col+2, 0]

        vertical_treansformed_pixels = vertical_filter * local_pixels
        vertical_score = vertical_treansformed_pixels.sum() / 8

        horizontal_treansformed_pixels = horizontal_filter*local_pixels
        horizontal_score = horizontal_treansformed_pixels.sum() / 4
        
        edge_score = (vertical_score ** 2 + horizontal_score ** 2) ** 0.5
        edges_img[row, col] = [edge_score] * 3

edges_img = edges_img/edges_img.max()

# %%
plt.imshow(edges_img)
